# %% [markdown]
# <a href="https://colab.research.google.com/github/kundansingh1149/Kundan-Singh/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas as pd
# dic1 = {
#     "name": [
#         "Aman Sharma", "Riya Verma", "Rahul Singh", "Neha Gupta", "Karan Mehta",
#         "Priya Yadav", "Mohit Raj", "Sneha Kapoor", "Arjun Malhotra", "Ishita Jain",
#         "Vikram Sethi", "Komal Arora", "Deepak Rana", "Shreya Bansal", "Aditya Khurana",
#         "Pooja Saxena", "Manish Thakur", "Anjali Chauhan", "Sandeep Joshi", "Nisha Rawat",
#         "Varun Ahuja", "Simran Kaur", "Rohit Sharma", "Tanya Oberoi", "Raghav Kapoor",
#         "Meera Nair", "Harsh Vardhan", "Kritika Soni", "Abhishek Tandon", "Aditi Mishra",
#         "Yuvraj Singh", "Sakshi Gupta", "Devansh Raina", "Muskan Sharma", "Rohan Verma",
#         "Chahat Gill", "Sameer Puri", "Ananya Iyer", "Gaurav Yadav", "Shruti Arora",
#         "Tanishq Verma", "Kunal Bhatia", "Ayesha Khan", "Tejas Nair", "Manya Kapoor",
#         "Ishaan Sharma", "Ritu Raj", "Aarav Malhotra", "Divya Sethi" , "King"
#     ],

#     "marks": [
#         23, 25, 27, 22, 30,
#     24, 28, 26, 29, 21,
#     31, 32, 27, 24, 26,
#     25, 28, 23, 29, 30,
#     22, 27, 33, 24, 26,
#     25, 29, 22, 28, 27,
#     23, 26, 24, 25, 30,
#     27, 28, 22, 29, 31,
#     26, 24, 23, 28, 27,
#     25, 29, 30, 22, 24,
#     ],

#     "city": [
#         "Delhi", "Mumbai", "Chennai", "Kolkata", "Bengaluru",
#         "Hyderabad", "Pune", "Jaipur", "Ahmedabad", "Lucknow",
#         "Kanpur", "Surat", "Indore", "Bhopal", "Nagpur",
#         "Patna", "Ranchi", "Chandigarh", "Jammu", "Amritsar",
#         "Ludhiana", "Noida", "Gurugram", "Vadodara", "Rajkot",
#         "Varanasi", "Prayagraj", "Meerut", "Agra", "Dehradun",
#         "Haridwar", "Udaipur", "Jodhpur", "Kota", "Gwalior",
#         "Faridabad", "Ghaziabad", "Thane", "Nashik", "Aurangabad",
#         "Coimbatore", "Madurai", "Mysuru", "Mangaluru", "Visakhapatnam",
#         "Vijayawada", "Guwahati", "Shimla", "Srinagar", "Panaji"
#     ]
# }

# # print("Length of name list:", len(dic1["name"]))
# # print("Length of marks list:", len(dic1["marks"]))
# # print("Length of city list:", len(dic1["city"]))


# df= pd.DataFrame(dic1)
# # print the dATA frame
# print(df)


# # save to CSV
# df.to_csv('detail_not.csv', index = False)


# # print marks column
# marks_series = df["marks"]
# print(marks_series)


# # Head, tail, info, describe
# # print(df.head())
# # print(df.tail())
# # print(df.info())
# # print(df.describe())
# print(df["name"])
# print(df[["name","city"]])
# print(df.loc[1])
# print(df.iloc[1])




# import pandas as pd

# df = pd.DataFrame({
#     "Name": ["Aman", "Rohit", "Suman"],
#     "Age": [22, 23, 24],
# }, index=[101, 102, 103])

# print(df.loc[101])   # Row with label 102
# print(df.iloc[1])    # Row in 2nd position
# print(df.index)








# import pandas as pd
# data = {
#     "Name": [
#         "Aman","Rahul","Priya","Simran","Vikas","Rohit","Sneha","Arjun","Neha","Karan",
#         "Pooja","Manish","Komal","Saurav","Anjali","Tarun","Riya","Kabir","Divya","Ishaan",
#         None,"Meera","Ankit","Sanya","Harsh","Naina",None,"Yash","Tanvi","Gauri",
#         "Farhan","Sakshi","Aditya","Raman","Tina","Laksh","Shivani","Rehan","Pinky",None,
#         "Gopal","Monika","Jatin","Isha","Ritesh","Reema",None,"Parth","Gayatri","Om"
#     ],

#     "Age": [
#         21,25,19,22,None,24,26,23,28,22,
#         21,None,27,20,23,24,22,None,29,21,
#         25,26,24,23,None,27,28,22,24,21,
#         23,None,25,29,20,22,24,None,26,27,
#         28,21,None,23,24,22,20,None,26,25
#     ],

#     "Marks": [
#         85,90,76,None,88,92,81,77,89,91,
#         None,84,79,93,87,80,None,82,91,78,
#         75,None,88,85,92,79,83,None,90,88,
#         91,76,None,84,74,82,None,88,92,89,
#         85,None,90,78,82,87,91,None,80,86
#     ]
# }

# df=pd.DataFrame(data)
# df.to_csv("python.csv")



#df = pd.DataFrame(data)
#print(df)

#df['Name']= df['Name'].fillna("Unknown")
#df['Age']= df['Age'].fillna(df['Age'].mean())
#df['Marks']= df['Marks'].fillna(df['Marks'].median())

#print(df)
#df.to_csv("aman.csv")

# %%
# n= int(input("enter the number:"))
# a= int(input("enter the lower range:"))
# b= int(input("enter the upper range:"))
# for i in range(a,b+1):
#   print(f"{n} x {i} = {n*i}")

# %%
# n= int(input("enter the number:"))
# for i in range(2, n):
#   if(n%i==0):
#     print("number is not prime")
#     break
#   else:
#     print("number is prime")
#     break

# %%
# import pandas as pd
# df= pd.DataFrame({
#     "Name": ["Aman","Rohit","Suman"],
#     "Age": [22, 23, 24],
#     }, index=[101, 102, 103])
# print(df.loc[102])
# print(df.iloc[1])
# print(df.index)

# %%
# import pandas as pd
# import numpy as np



# data = {

#     "Order_ID": [
#         2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#         2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#         2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030,
#         2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040,
#         2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050
#     ],

#     "Product": [
#         "Laptop", "Mobile", "Tablet", "Laptop", "Headphone",
#         "Mobile", "Tablet", "Laptop", "Mobile", "Tablet",
#         "Laptop", "Headphone", "Mobile", "Tablet", "Laptop",
#         "Mobile", "Tablet", "Laptop", "Headphone", "Mobile",
#         "Tablet", "Laptop", "Mobile", "Tablet", "Laptop",
#         "Headphone", "Mobile", "Tablet", "Laptop", "Mobile",
#         "Tablet", "Laptop", "Headphone", "Mobile", "Tablet",
#         "Laptop", "Mobile", "Tablet", "Laptop", "Headphone",
#         "Mobile", "Tablet", "Laptop", "Mobile", "Tablet",
    #     "Laptop", "Headphone", "Mobile", "Tablet", "Laptop"
    # ],

    # "Quantity": [
    #     2, 1, 3, 2, 4, 1, 2, 3, 1, 2,
    #     4, 2, 1, 3, 2, 4, 1, 2, 3, 1,
    #     2, 4, 1, 3, 2, 1, 4, 2, 3, 1,
    #     2, 4, 1, 3, 2, 1, 4, 2, 3, 1,
    #     2, 4, 1, 3, 2, 1, 4, 2, 3, 2
    # ],

    # "Price": [
    #     70000, 50000, 30000, 70000, 2000,
    #     50000, 30000, 70000, 50000, 30000,
    #     70000, 2000, 50000, 30000, 70000,
    #     50000, 30000, 70000, 2000, 50000,
    #     30000, 70000, 50000, 30000, 70000,
    #     2000, 50000, 30000, 70000, 50000,
    #     30000, 70000, 2000, 50000, 30000,
    #     70000, 50000, 30000, 70000, 2000,
    #     50000, 30000, 70000, 50000, 30000,
    #     70000, 2000, 50000, 30000, 70000
    # ],

    # "Region": [
    #     "North", "South", "East", "West", "North",
#         "South", "East", "West", "North", "South",
#         "East", "West", "North", "South", "East",
#         "West", "North", "South", "East", "West",
#         "North", "South", "East", "West", "North",
#         "South", "East", "West", "North", "South",
#         "East", "West", "North", "South", "East",
#         "West", "North", "South", "East", "West",
#         "North", "South", "East", "West", "North",
#         "South", "East", "West", "North", "South"
#     ]

# }

# df = pd.DataFrame(data)
# print(df)


# df.to_csv("sales_data.csv", index=False)
# Out:
#     Order_ID    Product  Quantity  Price Region
# 0       2001     Laptop         2  70000  North
# 1       2002     Mobile         1  50000  South
# 2       2003     Tablet         3  30000   East
# 3       2004     Laptop         2  70000   West
# 4       2005  Headphone         4   2000  North
# 5       2006     Mobile         1  50000  South
# 6       2007     Tablet         2  30000   East
# 7       2008     Laptop         3  70000   West
# 8       2009     Mobile         1  50000  North
# 9       2010     Tablet         2  30000  South
# 10      2011     Laptop         4  70000   East
# 11      2012  Headphone         2   2000   West
# 12      2013     Mobile         1  50000  North
# 13      2014     Tablet         3  30000  South
# 14      2015     Laptop         2  70000   East
# 15      2016     Mobile         4  50000   West
# 16      2017     Tablet         1  30000  North
# 17      2018     Laptop         2  70000  South
# 18      2019  Headphone         3   2000   East
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data = {
    "Date": pd.date_range(start="2024-01-01", periods=12, freq="M"),
    "Product": ["Laptop", "Mobile", "Tablet", "Laptop", "Mobile", "Tablet",
                "Laptop", "Mobile", "Tablet", "Laptop", "Mobile", "Tablet"],
    "Units_Sold": np.random.randint(20, 100, 12),
    "Price": [60000, 25000, 20000] * 4,
    "Cost": [45000, 18000, 14000] * 4
}

df = pd.DataFrame(data)
print(df)




df.to_csv("sales_data.csv", index=False)





df["Sales"] = df["Units_Sold"] * df["Price"]
df["Profit"] = df["Units_Sold"] * (df["Price"] - df["Cost"])

print("\nSales Data:\n", df)


total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()

print("\nTotal Sales:", total_sales)
print("Total Profit:", total_profit)


top_products = df.groupby("Product")["Units_Sold"].sum().sort_values(ascending=False)
print("\nTop Selling Products:\n", top_products)


monthly_sales = df.groupby("Date")["Sales"].sum()

plt.figure()
plt.plot(monthly_sales.index, monthly_sales.values, marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


profit_by_product = df.groupby("Product")["Profit"].sum()

plt.figure()
profit_by_product.plot(kind="bar")
plt.title("Profit by Product")
plt.xlabel("Product")
plt.ylabel("Profit")
plt.show()


df["Sales_Forecast"] = df["Sales"].rolling(window=3).mean()


plt.figure()
plt.plot(df["Date"], df["Sales"], label="Actual Sales")
plt.plot(df["Date"], df["Sales_Forecast"], label="Forecast", linestyle="--")
plt.title("Sales Forecast")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-249140221.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   "Date": pd.date_range(start="2024-01-01", periods=12, freq="M"),
#          Date Product  Units_Sold  Price   Cost
# 0  2024-01-31  Laptop          39  60000  45000
# 1  2024-02-29  Mobile          76  25000  18000
# 2  2024-03-31  Tablet          22  20000  14000
# 3  2024-04-30  Laptop          75  60000  45000
# 4  2024-05-31  Mobile          21  25000  18000
# 5  2024-06-30  Tablet          94  20000  14000
# 6  2024-07-31  Laptop          60  60000  45000
# 7  2024-08-31  Mobile          94  25000  18000
# 8  2024-09-30  Tablet          97  20000  14000
# 9  2024-10-31  Laptop          51  60000  45000
# 10 2024-11-30  Mobile          93  25000  18000
# 11 2024-12-31  Tablet          60  20000  14000
#
# Sales Data:
#           Date Product  Units_Sold  Price   Cost    Sales   Profit
# ...
